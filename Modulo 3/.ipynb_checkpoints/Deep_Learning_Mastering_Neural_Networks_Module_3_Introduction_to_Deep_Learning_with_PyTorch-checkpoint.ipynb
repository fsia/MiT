# %% [markdown]
# # **Módulo 3: Introdução à aprendizagem profunda com PyTorch**
#
# ## Introdução
# Nos *notebooks* anteriores, criamos, treinamos e avaliamos redes neurais usando classes de Python que desenvolvemos. Existem muitas bibliotecas de código aberto que ajudam a otimizar e tornar o processo de criação desses modelos repetível. Neste *notebook*, vamos analisar uma das mais populares: o PyTorch.
#
# Após conhecermos, no *notebook* anterior, os conceitos básicos do uso de tensores no [Pytorch](https://pytorch.org/), vamos usá-los para criar modelos de aprendizagem profunda. No próximo *notebook*, passaremos por um exemplo de criação de um modelo de classificação e um modelo de regressão no PyTorch utilizando um grande conjunto de dados disponível publicamente.

# %% [markdown]
# ## Classificação com PyTorch
#
# Neste primeiro exemplo, usaremos o PyTorch para realizar uma tarefa de classificação binária em um conjunto de dados de código aberto. O conjunto de dados em questão é o conjunto de dados de idade de abalones e pode ser encontrado [aqui](https://archive.ics.uci.edu/dataset/1/abalone).
#
# [Abalone](https://en.wikipedia.org/wiki/Abalone) é um tipo de molusco marinho e sua idade pode ser determinada por meio de uma tarefa extremamente manual de contagem de anéis dentro de sua concha. Esse conjunto de dados contém várias medidas que podem ser usadas para prever o número de anéis.

# %% [markdown]
# ### Download do conjunto de dados e importação de módulos

# %%
# Faça o download dos arquivos .csv dos abalones a partir do arquivo de dados, se necessário.
# !rm abalone.data abalone.names
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.names
# Out:
# rm: cannot remove 'abalone.data': No such file or directory
# rm: cannot remove 'abalone.names': No such file or directory
# --2023-12-18 19:36:57--  https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘abalone.data’
#
# abalone.data            [   <=>              ] 187.38K   248KB/s    in 0.8s
#
# 2023-12-18 19:36:59 (248 KB/s) - ‘abalone.data’ saved [191873]
#
# --2023-12-18 19:36:59--  https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘abalone.names’
#
# abalone.names           [ <=>                ]   4.22K  --.-KB/s    in 0.001s
#
# 2023-12-18 19:36:59 (6.09 MB/s) - ‘abalone.names’ saved [4319]

# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.16.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.1.2 in /opt/conda/lib/python3.11/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (4.8.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.2->torchvision) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->torchvision) (12.3.101)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch==2.1.2->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch==2.1.2->torchvision) (1.3.0)
# Downloading torchvision-0.16.2-cp311-cp311-manylinux1_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 4.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torchvision
# Successfully installed torchvision-0.16.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Como você pode ver, agora precisamos de vários módulos diferentes
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from torch.utils.data import TensorDataset, DataLoader

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time, copy

# %% [markdown]
# ### Preparar os dados dos abalones para classificação
#
# Queremos criar um problema de classificação para diferenciar abalones jovens (young) e adultos (old). Consideraremos qualquer abalone com menos de 10 anéis como jovem e todos os outros como adultos.

# %%
column_names = ["Sex", "Length", "Diameter", "Height", "Whole weight",
                "Shucked weight", "Viscera weight", "Shell weights", "Rings"]
df = pd.read_csv('abalone.data', header=None, names=column_names)
df['Old'] = 0  # Por padrão, o abalone é considerado jovem
df.loc[(df['Rings'] >= 10), 'Old'] = 1 # 10 anéis ou mais significa que um abalone é considerado adulto
class_labels = ['Young', 'Old']   # [0, 1], [N, P]
numerical_feature_columns = column_names[1:5] # Primeiramente, queremos classificar apenas com atributos numéricos, excluindo o sexo e considerando apenas o peso total
print(numerical_feature_columns)
label_column = 'Old'


df.head() # Visualizar um subconjunto do conjunto de dados
# Out:
# ['Length', 'Diameter', 'Height', 'Whole weight']
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weights  Rings  Old
# 0          0.150     15    1
# 1          0.070      7    0
# 2          0.210      9    0
# 3          0.155     10    1
# 4          0.055      7    0

# %% [markdown]
# ### Divisão e padronização de treinamento/validação/teste
#
# Para esta tarefa de classificação, dividiremos nosso conjunto de dados em três subconjuntos diferentes, conforme descrito anteriormente no módulo. O subconjunto de treinamento, o maior, será usado para treinar e otimizar os pesos do modelo. Em seguida, temos o subconjunto de validação, que será usado como uma avaliação imparcial do modelo e ajudará a ajustar diferentes hiperparâmetros. Por fim, temos o subconjunto de teste, usado para uma avaliação imparcial do modelo totalmente treinado.
#
# Além disso, gostaríamos de realizar a padronização dos dados removendo a média e dimensionando pela variância. Faremos isso em cada um dos atributos, mas queremos garantir que essa função de padronização seja calculada no subconjunto de dados de treinamento. Em seguida, aplicamos a função de padronização aos conjuntos de validação e teste. Ao garantir que a padronização seja calculada apenas no subconjunto de treinamento, nos asseguramos que nenhuma informação dos conjuntos de validação ou teste esteja vazando para o subconjunto de treinamento.
#
# Abaixo, fornecemos uma função para dividir um determinado conjunto de dados em treinamento/validação/teste, sendo 60/20/20, e executar a padronização de dados usando a classe StandardScaler do sklearn para consumo do PyTorch:

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

def train_test_val_split(df, feature_columns, label_column, ct):
  # Primeiro, realizar uma divisão de treinamento/teste de 80/20
  initial_train_split = df.sample(frac=.8,random_state=42)
  test = df.drop(initial_train_split.index)

  # Em seguida, realizar uma divisão de treinamento/validação de 75/25
  train = initial_train_split.sample(frac=.75, random_state=42)
  val = initial_train_split.drop(train.index)

  # Separar todos os conjuntos de dados em atributos e rótulos (x e y)
  train_x = train[feature_columns]
  # Não será realizada transformação nos rótulos, então podem ser convertidos diretamente em tensores torch
  train_y = torch.from_numpy(train[label_column].values)

  val_x = val[feature_columns]
  val_y = torch.from_numpy(val[label_column].values)

  test_x = test[feature_columns]
  test_y = torch.from_numpy(test[label_column].values)

  # Ajustar o ColumnTransformer ao conjunto de dados de treinamento
  ct.fit(train_x)

  # Realizar a padronização em cada um dos conjuntos de dados x
  train_x = ct.transform(train_x)
  val_x = ct.transform(val_x)
  test_x = ct.transform(test_x)

  # Transformar nossos conjuntos de dados em tensores torch
  train_x = torch.from_numpy(train_x).float()
  val_x = torch.from_numpy(val_x).float()
  test_x = torch.from_numpy(test_x).float()

  # Criar os conjuntos de dados de entrada-rótulo para serem consumidos pelo PyTorch
  train_dataset = TensorDataset(train_x, train_y)
  test_dataset = TensorDataset(test_x, test_y)
  val_dataset = TensorDataset(val_x, val_y)
  return train_dataset, test_dataset, val_dataset

# %%
# Criar nosso StandardScaler para ser usado na padronização dos dados
# Mais informações aqui: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html#sklearn.compose.ColumnTransformer
ct = ColumnTransformer([('numerical_features', StandardScaler(), numerical_feature_columns)], remainder='passthrough')

train_dataset, test_dataset, val_dataset = train_test_val_split(df, numerical_feature_columns, label_column, ct)

# %% [markdown]
# ### Hiperparâmetros do modelo e definição
# Agora que podemos dividir facilmente nosso conjunto de dados em subconjuntos de treinamento, validação e teste, voltamos para a seleção de nossos hiperparâmetros. Esses hiperparâmetros incluem decisões de arquitetura do modelo (número de camadas ocultas) e parâmetros externos de treinamento, como tamanho do lote, taxa de aprendizado e número de épocas de treinamento.

# %%
# Configuração do dispositivo (treinar nosso modelo na GPU se estiver disponível, o que é muito mais rápido)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hiperparâmetros

# Arquitetura do modelo
input_size = len(numerical_feature_columns) # Garantir a remoção da coluna de index
hidden_size1 = 64
hidden_size2 = 64
hidden_size3 = 64
num_classes = 2

# Parâmetros externos de treinamento
batch_size = 10
learning_rate = 0.001
num_epochs = 50

# %% [markdown]
# ### Seleção de hiperparâmetros
#
# Neste passo a passo, usaremos nosso conjunto de validação para determinar dois hiperparâmetros diferentes.
#
# O primeiro é o número total de épocas de treinamento. No final de todo o processo de treinamento, selecionaremos os pesos da época com a maior precisão de validação.
#
# O segundo é o número de camadas. Vamos testar tanto uma rede com 2 camadas ocultas quanto uma com 3 camadas ocultas. Novamente, aquela que tiver o melhor desempenho no conjunto de validação será nosso modelo final escolhido.

# %%
# Modelo de classificação simples com duas camadas ocultas
class SimpleClassifier2Layer(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, num_classes):
        super(SimpleClassifier2Layer, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            nn.Linear(hidden_size2, num_classes),
        )

    def forward(self, x):
        return self.layers(x)

# Modelo de classificação simples com três camadas ocultas
class SimpleClassifier3Layer(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, num_classes):
        super(SimpleClassifier3Layer, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            nn.Linear(hidden_size2, hidden_size3),
            nn.ReLU(),
            nn.Linear(hidden_size3, num_classes),
        )

    def forward(self, x):
        return self.layers(x)

# %%
print(input_size) #Parametros de entrada
print(hidden_size1) #Parametros na primeira camada escondida
print(hidden_size2) #Parametros na segunda camada escondida
print(num_classes) #Parametros classificatorios de saida
# Out:
# 4
# 64
# 64
# 2

# %%
two_layer_model = SimpleClassifier2Layer(input_size, hidden_size1, hidden_size2, num_classes).to(device)
print(two_layer_model)

three_layer_model = SimpleClassifier3Layer(input_size, hidden_size1, hidden_size2, hidden_size3, num_classes).to(device)
print(three_layer_model)
# Out:
# SimpleClassifier2Layer(
#   (layers): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# SimpleClassifier3Layer(
#   (layers): Sequential(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Preparação final dos dados
#
# Agora que temos nosso modelo e nossos hiperparâmetros definidos, podemos realizar a última etapa de preparação dos dados. Vamos usar uma classe incorporada do PyTorch chamada DataLoader, com nosso tamanho de lote especificado anteriormente. Esse DataLoader será responsável por fornecer os lotes de dados ao modelo durante o treinamento.

# %%
dataloaders = {'train': DataLoader(train_dataset, batch_size=batch_size),
               'val': DataLoader(val_dataset, batch_size=batch_size),
               'test': DataLoader(test_dataset, batch_size=batch_size)}

dataset_sizes = {'train': len(train_dataset),
                 'val': len(val_dataset),
                 'test': len(test_dataset)}
print(f'dataset_sizes = {dataset_sizes}')
# Out:
# dataset_sizes = {'train': 2506, 'val': 836, 'test': 835}

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7f5e74edb610>,
#  'val': <torch.utils.data.dataloader.DataLoader at 0x7f5e75143ed0>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x7f5e74edbd50>}

# %% [markdown]
# ### Treinando o modelo
#
# Agora que temos nossa arquitetura do modelo definida e nossos dados prontos para uso, precisamos definir a função de treinamento. Essa função será responsável por atualizar todos os pesos do modelo.

# %%
# De https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

def train_model(model, dataloaders, dataset_sizes, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict()) # Manter os melhores pesos armazenados separadamente
    best_acc = 0.0
    best_epoch = 0

    # Cada época tem uma fase de treinamento, validação e teste
    phases = ['train', 'val', 'test']

    # Acompanhar a evolução da perda e da precisão durante o treinamento
    training_curves = {}
    for phase in phases:
        training_curves[phase+'_loss'] = []
        training_curves[phase+'_acc'] = []

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()  # Definir o modelo para o modo de treinamento
            else:
                model.eval()   # Definir o modelo para o modo de avaliação

            running_loss = 0.0
            running_corrects = 0

            # Iterar sobre os dados
            for inputs, labels in dataloaders[phase]:
                # Isso garante que todos os nossos pontos de dados sejam nivelados
                # antes de alimentá-los em nosso modelo
                inputs = inputs.view(inputs.shape[0],-1)
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zerar os gradientes dos parâmetros
                optimizer.zero_grad()

                # Propagação (forward)
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, predictions = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Retropropagação (backward) + atualizar pesos somente se estiver na fase de treinamento
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Estatísticas
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(predictions == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            training_curves[phase+'_loss'].append(epoch_loss)
            training_curves[phase+'_acc'].append(epoch_acc)

            print(f'{phase:5} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Copiar profundamente o modelo se ele tiver a melhor precisão (com base na validação)
            if phase == 'val' and epoch_acc > best_acc:
                best_epoch = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f} at epoch {best_epoch}')

    # Carregar os pesos do melhor modelo
    model.load_state_dict(best_model_wts)

    return model, training_curves

# %% [markdown]
# Escrevemos nossa função de treinamento acima para ser independente da arquitetura. Isso significa que podemos usar a mesma função para treinar as redes de duas camadas ocultas e de três camadas ocultas.

# %%
# Treinamento com duas camadas ocultas
# Perda e otimizador
criterion = nn.CrossEntropyLoss() # CrossEntropyLoss para classificação!
optimizer = torch.optim.Adam(two_layer_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

# Treinar o modelo. Também armazenaremos os resultados do treinamento para visualização
two_layer_model, training_curves_two_layer = train_model(two_layer_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.4958 Acc: 0.7610
# val   Loss: 0.4442 Acc: 0.7955
# test  Loss: 0.5247 Acc: 0.7174
#
# Epoch 2/50
# ----------
# train Loss: 0.4949 Acc: 0.7582
# val   Loss: 0.4456 Acc: 0.7955
# test  Loss: 0.5242 Acc: 0.7174
#
# Epoch 3/50
# ----------
# train Loss: 0.4946 Acc: 0.7574
# val   Loss: 0.4466 Acc: 0.7978
# test  Loss: 0.5246 Acc: 0.7210
#
# Epoch 4/50
# ----------
# train Loss: 0.4937 Acc: 0.7586
# val   Loss: 0.4476 Acc: 0.7967
# test  Loss: 0.5246 Acc: 0.7198
#
# Epoch 5/50
# ----------
# train Loss: 0.4930 Acc: 0.7562
# val   Loss: 0.4481 Acc: 0.7978
# test  Loss: 0.5247 Acc: 0.7186
#
# Epoch 6/50
# ----------
# train Loss: 0.4927 Acc: 0.7574
# val   Loss: 0.4489 Acc: 0.7978
# test  Loss: 0.5249 Acc: 0.7186
#
# Epoch 7/50
# ----------
# train Loss: 0.4918 Acc: 0.7570
# val   Loss: 0.4500 Acc: 0.7990
# test  Loss: 0.5254 Acc: 0.7162
#
# Epoch 8/50
# ----------
# train Loss: 0.4914 Acc: 0.7574
# val   Loss: 0.4507 Acc: 0.7990
# test  Loss: 0.5256 Acc: 0.7186
#
# Epoch 9/50
# ----------
# train Loss: 0.4908 Acc: 0.7578
# val   Loss: 0.4515 Acc: 0.7967
# test  Loss: 0.5261 Acc: 0.7186
#
# Epoch 10/50
# ----------
# train Loss: 0.4904 Acc: 0.7594
# val   Loss: 0.4523 Acc: 0.7978
# test  Loss: 0.5262 Acc: 0.7186
#
# Epoch 11/50
# ----------
# train Loss: 0.4901 Acc: 0.7594
# val   Loss: 0.4529 Acc: 0.7955
# test  Loss: 0.5268 Acc: 0.7174
#
# Epoch 12/50
# ----------
# train Loss: 0.4894 Acc: 0.7598
# val   Loss: 0.4532 Acc: 0.7955
# test  Loss: 0.5267 Acc: 0.7210
#
# Epoch 13/50
# ----------
# train Loss: 0.4893 Acc: 0.7602
# val   Loss: 0.4538 Acc: 0.7931
# test  Loss: 0.5270 Acc: 0.7222
#
# Epoch 14/50
# ----------
# train Loss: 0.4888 Acc: 0.7598
# val   Loss: 0.4547 Acc: 0.7943
# test  Loss: 0.5275 Acc: 0.7222
#
# Epoch 15/50
# ----------
# train Loss: 0.4884 Acc: 0.7614
# val   Loss: 0.4547 Acc: 0.7943
# test  Loss: 0.5274 Acc: 0.7198
#
# Epoch 16/50
# ----------
# train Loss: 0.4882 Acc: 0.7622
# val   Loss: 0.4554 Acc: 0.7943
# test  Loss: 0.5279 Acc: 0.7210
#
# Epoch 17/50
# ----------
# train Loss: 0.4878 Acc: 0.7618
# val   Loss: 0.4558 Acc: 0.7955
# test  Loss: 0.5280 Acc: 0.7198
#
# Epoch 18/50
# ----------
# train Loss: 0.4875 Acc: 0.7622
# val   Loss: 0.4562 Acc: 0.7967
# test  Loss: 0.5284 Acc: 0.7198
#
# Epoch 19/50
# ----------
# train Loss: 0.4871 Acc: 0.7614
# val   Loss: 0.4561 Acc: 0.7967
# test  Loss: 0.5283 Acc: 0.7198
#
# Epoch 20/50
# ----------
# train Loss: 0.4868 Acc: 0.7614
# val   Loss: 0.4566 Acc: 0.7990
# test  Loss: 0.5287 Acc: 0.7222
#
# Epoch 21/50
# ----------
# train Loss: 0.4865 Acc: 0.7606
# val   Loss: 0.4566 Acc: 0.7990
# test  Loss: 0.5289 Acc: 0.7210
#
# Epoch 22/50
# ----------
# train Loss: 0.4862 Acc: 0.7610
# val   Loss: 0.4567 Acc: 0.7967
# test  Loss: 0.5291 Acc: 0.7210
#
# Epoch 23/50
# ----------
# train Loss: 0.4860 Acc: 0.7610
# val   Loss: 0.4567 Acc: 0.7967
# test  Loss: 0.5292 Acc: 0.7198
#
# Epoch 24/50
# ----------
# train Loss: 0.4857 Acc: 0.7614
# val   Loss: 0.4567 Acc: 0.7967
# test  Loss: 0.5293 Acc: 0.7186
#
# Epoch 25/50
# ----------
# train Loss: 0.4855 Acc: 0.7614
# val   Loss: 0.4566 Acc: 0.7955
# test  Loss: 0.5295 Acc: 0.7174
#
# Epoch 26/50
# ----------
# train Loss: 0.4852 Acc: 0.7622
# val   Loss: 0.4566 Acc: 0.7955
# test  Loss: 0.5297 Acc: 0.7186
#
# Epoch 27/50
# ----------
# train Loss: 0.4850 Acc: 0.7614
# val   Loss: 0.4567 Acc: 0.7955
# test  Loss: 0.5299 Acc: 0.7162
#
# Epoch 28/50
# ----------
# train Loss: 0.4846 Acc: 0.7630
# val   Loss: 0.4567 Acc: 0.7955
# test  Loss: 0.5300 Acc: 0.7174
#
# Epoch 29/50
# ----------
# train Loss: 0.4845 Acc: 0.7634
# val   Loss: 0.4567 Acc: 0.7955
# test  Loss: 0.5301 Acc: 0.7174
#
# Epoch 30/50
# ----------
# train Loss: 0.4842 Acc: 0.7638
# val   Loss: 0.4564 Acc: 0.7955
# test  Loss: 0.5302 Acc: 0.7174
#
# Epoch 31/50
# ----------
# train Loss: 0.4840 Acc: 0.7634
# val   Loss: 0.4564 Acc: 0.7955
# test  Loss: 0.5304 Acc: 0.7174
#
# Epoch 32/50
# ----------
# train Loss: 0.4838 Acc: 0.7634
# val   Loss: 0.4562 Acc: 0.7955
# test  Loss: 0.5304 Acc: 0.7186
#
# Epoch 33/50
# ----------
# train Loss: 0.4836 Acc: 0.7638
# val   Loss: 0.4562 Acc: 0.7955
# test  Loss: 0.5305 Acc: 0.7198
#
# Epoch 34/50
# ----------
# train Loss: 0.4834 Acc: 0.7630
# val   Loss: 0.4561 Acc: 0.7955
# test  Loss: 0.5306 Acc: 0.7210
#
# Epoch 35/50
# ----------
# train Loss: 0.4833 Acc: 0.7630
# val   Loss: 0.4559 Acc: 0.7955
# test  Loss: 0.5307 Acc: 0.7210
#
# Epoch 36/50
# ----------
# train Loss: 0.4831 Acc: 0.7630
# val   Loss: 0.4559 Acc: 0.7943
# test  Loss: 0.5309 Acc: 0.7210
#
# Epoch 37/50
# ----------
# train Loss: 0.4829 Acc: 0.7626
# val   Loss: 0.4556 Acc: 0.7943
# test  Loss: 0.5309 Acc: 0.7210
#
# Epoch 38/50
# ----------
# train Loss: 0.4827 Acc: 0.7630
# val   Loss: 0.4556 Acc: 0.7943
# test  Loss: 0.5310 Acc: 0.7198
#
# Epoch 39/50
# ----------
# train Loss: 0.4826 Acc: 0.7630
# val   Loss: 0.4554 Acc: 0.7943
# test  Loss: 0.5311 Acc: 0.7210
#
# Epoch 40/50
# ----------
# train Loss: 0.4825 Acc: 0.7626
# val   Loss: 0.4554 Acc: 0.7943
# test  Loss: 0.5311 Acc: 0.7222
#
# Epoch 41/50
# ----------
# train Loss: 0.4823 Acc: 0.7626
# val   Loss: 0.4553 Acc: 0.7943
# test  Loss: 0.5312 Acc: 0.7234
#
# Epoch 42/50
# ----------
# train Loss: 0.4821 Acc: 0.7626
# val   Loss: 0.4553 Acc: 0.7943
# test  Loss: 0.5313 Acc: 0.7222
#
# Epoch 43/50
# ----------
# train Loss: 0.4820 Acc: 0.7626
# val   Loss: 0.4552 Acc: 0.7943
# test  Loss: 0.5314 Acc: 0.7234
#
# Epoch 44/50
# ----------
# train Loss: 0.4819 Acc: 0.7626
# val   Loss: 0.4550 Acc: 0.7931
# test  Loss: 0.5314 Acc: 0.7210
#
# Epoch 45/50
# ----------
# train Loss: 0.4818 Acc: 0.7626
# val   Loss: 0.4550 Acc: 0.7931
# test  Loss: 0.5315 Acc: 0.7222
#
# Epoch 46/50
# ----------
# train Loss: 0.4816 Acc: 0.7622
# val   Loss: 0.4549 Acc: 0.7931
# test  Loss: 0.5315 Acc: 0.7210
#
# Epoch 47/50
# ----------
# train Loss: 0.4815 Acc: 0.7618
# val   Loss: 0.4548 Acc: 0.7931
# test  Loss: 0.5316 Acc: 0.7198
#
# Epoch 48/50
# ----------
# train Loss: 0.4814 Acc: 0.7622
# val   Loss: 0.4548 Acc: 0.7931
# test  Loss: 0.5317 Acc: 0.7198
#
# Epoch 49/50
# ----------
# train Loss: 0.4813 Acc: 0.7622
# val   Loss: 0.4547 Acc: 0.7931
# test  Loss: 0.5318 Acc: 0.7198
#
# Epoch 50/50
# ----------
# train Loss: 0.4812 Acc: 0.7626
# val   Loss: 0.4546 Acc: 0.7931
# test  Loss: 0.5318 Acc: 0.7210
#
# Training complete in 0m 14s
# Best val Acc: 0.799043 at epoch 6

# %% [markdown]
# Para determinar o peso que gostaríamos de usar em nosso modelo final, procuraremos a época que teve o melhor desempenho no conjunto de validação.

# %%
# Treinamento com três camadas ocultas
# perda e otimizador
criterion = nn.CrossEntropyLoss() # CrossEntropyLoss for classification!
optimizer = torch.optim.Adam(three_layer_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

# Treinar o modelo. Também armazenaremos os resultados do treinamento para visualização
three_layer_model, training_curves_three_layer = train_model(three_layer_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5019 Acc: 0.7510
# val   Loss: 0.4447 Acc: 0.7967
# test  Loss: 0.5257 Acc: 0.7198
#
# Epoch 2/50
# ----------
# train Loss: 0.5000 Acc: 0.7522
# val   Loss: 0.4450 Acc: 0.7967
# test  Loss: 0.5263 Acc: 0.7186
#
# Epoch 3/50
# ----------
# train Loss: 0.4990 Acc: 0.7522
# val   Loss: 0.4457 Acc: 0.7990
# test  Loss: 0.5268 Acc: 0.7162
#
# Epoch 4/50
# ----------
# train Loss: 0.4981 Acc: 0.7514
# val   Loss: 0.4459 Acc: 0.7978
# test  Loss: 0.5268 Acc: 0.7138
#
# Epoch 5/50
# ----------
# train Loss: 0.4970 Acc: 0.7518
# val   Loss: 0.4461 Acc: 0.7931
# test  Loss: 0.5271 Acc: 0.7126
#
# Epoch 6/50
# ----------
# train Loss: 0.4962 Acc: 0.7514
# val   Loss: 0.4469 Acc: 0.7919
# test  Loss: 0.5275 Acc: 0.7090
#
# Epoch 7/50
# ----------
# train Loss: 0.4957 Acc: 0.7530
# val   Loss: 0.4469 Acc: 0.7943
# test  Loss: 0.5269 Acc: 0.7078
#
# Epoch 8/50
# ----------
# train Loss: 0.4947 Acc: 0.7514
# val   Loss: 0.4478 Acc: 0.7907
# test  Loss: 0.5278 Acc: 0.7102
#
# Epoch 9/50
# ----------
# train Loss: 0.4941 Acc: 0.7510
# val   Loss: 0.4480 Acc: 0.7919
# test  Loss: 0.5281 Acc: 0.7090
#
# Epoch 10/50
# ----------
# train Loss: 0.4934 Acc: 0.7510
# val   Loss: 0.4484 Acc: 0.7931
# test  Loss: 0.5281 Acc: 0.7090
#
# Epoch 11/50
# ----------
# train Loss: 0.4927 Acc: 0.7526
# val   Loss: 0.4490 Acc: 0.7931
# test  Loss: 0.5280 Acc: 0.7078
#
# Epoch 12/50
# ----------
# train Loss: 0.4922 Acc: 0.7530
# val   Loss: 0.4496 Acc: 0.7931
# test  Loss: 0.5281 Acc: 0.7138
#
# Epoch 13/50
# ----------
# train Loss: 0.4915 Acc: 0.7538
# val   Loss: 0.4504 Acc: 0.7931
# test  Loss: 0.5284 Acc: 0.7090
#
# Epoch 14/50
# ----------
# train Loss: 0.4910 Acc: 0.7554
# val   Loss: 0.4508 Acc: 0.7967
# test  Loss: 0.5288 Acc: 0.7126
#
# Epoch 15/50
# ----------
# train Loss: 0.4904 Acc: 0.7554
# val   Loss: 0.4515 Acc: 0.7943
# test  Loss: 0.5291 Acc: 0.7162
#
# Epoch 16/50
# ----------
# train Loss: 0.4900 Acc: 0.7538
# val   Loss: 0.4520 Acc: 0.7943
# test  Loss: 0.5293 Acc: 0.7162
#
# Epoch 17/50
# ----------
# train Loss: 0.4895 Acc: 0.7558
# val   Loss: 0.4527 Acc: 0.7931
# test  Loss: 0.5301 Acc: 0.7174
#
# Epoch 18/50
# ----------
# train Loss: 0.4889 Acc: 0.7562
# val   Loss: 0.4527 Acc: 0.7931
# test  Loss: 0.5299 Acc: 0.7162
#
# Epoch 19/50
# ----------
# train Loss: 0.4885 Acc: 0.7554
# val   Loss: 0.4533 Acc: 0.7907
# test  Loss: 0.5306 Acc: 0.7174
#
# Epoch 20/50
# ----------
# train Loss: 0.4881 Acc: 0.7550
# val   Loss: 0.4535 Acc: 0.7907
# test  Loss: 0.5308 Acc: 0.7138
#
# Epoch 21/50
# ----------
# train Loss: 0.4875 Acc: 0.7542
# val   Loss: 0.4537 Acc: 0.7919
# test  Loss: 0.5310 Acc: 0.7150
#
# Epoch 22/50
# ----------
# train Loss: 0.4870 Acc: 0.7546
# val   Loss: 0.4538 Acc: 0.7919
# test  Loss: 0.5312 Acc: 0.7138
#
# Epoch 23/50
# ----------
# train Loss: 0.4867 Acc: 0.7554
# val   Loss: 0.4544 Acc: 0.7919
# test  Loss: 0.5317 Acc: 0.7150
#
# Epoch 24/50
# ----------
# train Loss: 0.4863 Acc: 0.7538
# val   Loss: 0.4544 Acc: 0.7931
# test  Loss: 0.5318 Acc: 0.7162
#
# Epoch 25/50
# ----------
# train Loss: 0.4858 Acc: 0.7546
# val   Loss: 0.4545 Acc: 0.7931
# test  Loss: 0.5323 Acc: 0.7174
#
# Epoch 26/50
# ----------
# train Loss: 0.4854 Acc: 0.7550
# val   Loss: 0.4543 Acc: 0.7943
# test  Loss: 0.5324 Acc: 0.7186
#
# Epoch 27/50
# ----------
# train Loss: 0.4851 Acc: 0.7558
# val   Loss: 0.4545 Acc: 0.7931
# test  Loss: 0.5330 Acc: 0.7198
#
# Epoch 28/50
# ----------
# train Loss: 0.4847 Acc: 0.7566
# val   Loss: 0.4543 Acc: 0.7895
# test  Loss: 0.5330 Acc: 0.7162
#
# Epoch 29/50
# ----------
# train Loss: 0.4842 Acc: 0.7562
# val   Loss: 0.4543 Acc: 0.7907
# test  Loss: 0.5333 Acc: 0.7174
#
# Epoch 30/50
# ----------
# train Loss: 0.4838 Acc: 0.7570
# val   Loss: 0.4541 Acc: 0.7895
# test  Loss: 0.5336 Acc: 0.7162
#
# Epoch 31/50
# ----------
# train Loss: 0.4835 Acc: 0.7570
# val   Loss: 0.4540 Acc: 0.7895
# test  Loss: 0.5339 Acc: 0.7162
#
# Epoch 32/50
# ----------
# train Loss: 0.4832 Acc: 0.7594
# val   Loss: 0.4537 Acc: 0.7907
# test  Loss: 0.5343 Acc: 0.7162
#
# Epoch 33/50
# ----------
# train Loss: 0.4829 Acc: 0.7594
# val   Loss: 0.4537 Acc: 0.7919
# test  Loss: 0.5343 Acc: 0.7150
#
# Epoch 34/50
# ----------
# train Loss: 0.4826 Acc: 0.7598
# val   Loss: 0.4534 Acc: 0.7919
# test  Loss: 0.5346 Acc: 0.7150
#
# Epoch 35/50
# ----------
# train Loss: 0.4823 Acc: 0.7598
# val   Loss: 0.4533 Acc: 0.7919
# test  Loss: 0.5347 Acc: 0.7138
#
# Epoch 36/50
# ----------
# train Loss: 0.4819 Acc: 0.7606
# val   Loss: 0.4529 Acc: 0.7943
# test  Loss: 0.5347 Acc: 0.7138
#
# Epoch 37/50
# ----------
# train Loss: 0.4816 Acc: 0.7614
# val   Loss: 0.4530 Acc: 0.7943
# test  Loss: 0.5350 Acc: 0.7162
#
# Epoch 38/50
# ----------
# train Loss: 0.4814 Acc: 0.7622
# val   Loss: 0.4527 Acc: 0.7931
# test  Loss: 0.5352 Acc: 0.7174
#
# Epoch 39/50
# ----------
# train Loss: 0.4812 Acc: 0.7618
# val   Loss: 0.4525 Acc: 0.7931
# test  Loss: 0.5355 Acc: 0.7174
#
# Epoch 40/50
# ----------
# train Loss: 0.4809 Acc: 0.7630
# val   Loss: 0.4523 Acc: 0.7931
# test  Loss: 0.5356 Acc: 0.7198
#
# Epoch 41/50
# ----------
# train Loss: 0.4807 Acc: 0.7638
# val   Loss: 0.4522 Acc: 0.7931
# test  Loss: 0.5358 Acc: 0.7210
#
# Epoch 42/50
# ----------
# train Loss: 0.4804 Acc: 0.7638
# val   Loss: 0.4520 Acc: 0.7931
# test  Loss: 0.5361 Acc: 0.7210
#
# Epoch 43/50
# ----------
# train Loss: 0.4802 Acc: 0.7638
# val   Loss: 0.4519 Acc: 0.7943
# test  Loss: 0.5363 Acc: 0.7210
#
# Epoch 44/50
# ----------
# train Loss: 0.4799 Acc: 0.7634
# val   Loss: 0.4519 Acc: 0.7931
# test  Loss: 0.5366 Acc: 0.7198
#
# Epoch 45/50
# ----------
# train Loss: 0.4797 Acc: 0.7638
# val   Loss: 0.4517 Acc: 0.7931
# test  Loss: 0.5368 Acc: 0.7198
#
# Epoch 46/50
# ----------
# train Loss: 0.4795 Acc: 0.7642
# val   Loss: 0.4517 Acc: 0.7931
# test  Loss: 0.5370 Acc: 0.7198
#
# Epoch 47/50
# ----------
# train Loss: 0.4793 Acc: 0.7638
# val   Loss: 0.4515 Acc: 0.7919
# test  Loss: 0.5372 Acc: 0.7210
#
# Epoch 48/50
# ----------
# train Loss: 0.4791 Acc: 0.7630
# val   Loss: 0.4515 Acc: 0.7907
# test  Loss: 0.5374 Acc: 0.7210
#
# Epoch 49/50
# ----------
# train Loss: 0.4790 Acc: 0.7630
# val   Loss: 0.4512 Acc: 0.7907
# test  Loss: 0.5376 Acc: 0.7210
#
# Epoch 50/50
# ----------
# train Loss: 0.4788 Acc: 0.7630
# val   Loss: 0.4511 Acc: 0.7907
# test  Loss: 0.5378 Acc: 0.7198
#
# Training complete in 0m 17s
# Best val Acc: 0.799043 at epoch 2

# %% [markdown]
# Após nosso treinamento, observamos uma precisão comparável entre nossos dois modelos diferentes, portanto, usaremos o modelo de três camadas daqui para frente, mas exploraremos outros métodos para melhorar nosso desempenho.

# %% [markdown]
# ### Métricas e curvas de treinamento
#
# Abaixo, fornecemos funções para visualizar as curvas de treinamento e as métricas do problema de classificação. Sinta-se à vontade para usar essas funções no futuro!

# %%
def plot_training_curves(training_curves,
                         phases=['train', 'val', 'test'],
                         metrics=['loss','acc']):
    epochs = list(range(len(training_curves['train_loss'])))
    for metric in metrics:
        plt.figure()
        plt.title(f'Training curves - {metric}')
        for phase in phases:
            key = phase+'_'+metric
            if key in training_curves:
                plt.plot(epochs, training_curves[phase+'_'+metric])
        plt.xlabel('epoch')
        plt.legend(labels=phases)

def classify_predictions(model, device, dataloader):
    model.eval()   # Definir o modelo no modo de avaliação
    all_labels = torch.tensor([]).to(device)
    all_scores = torch.tensor([]).to(device)
    all_preds = torch.tensor([]).to(device)
    for inputs, labels in dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = torch.softmax(model(inputs),dim=1)
        _, preds = torch.max(outputs, 1)
        scores = outputs[:,1]
        all_labels = torch.cat((all_labels, labels), 0)
        all_scores = torch.cat((all_scores, scores), 0)
        all_preds = torch.cat((all_preds, preds), 0)
    return all_preds.detach().cpu(), all_labels.detach().cpu(), all_scores.detach().cpu()

def plot_regression(model, device, dataloader):
    preds, targets = regress_predictions(model, device, dataloader)
    plt.figure()
    plt.title(f'Regression results')
    plt.scatter(targets, preds)
    xmin = min(min(targets), min(preds))
    xmax = max(max(targets), max(targets))
    plt.plot([xmin, xmax], [xmin, xmax], 'black', linestyle='--', marker='')
    plt.xlabel('target value')
    plt.ylabel('prediced value')

def regress_predictions(model, device, dataloader):
    model.eval()   # Definir o modelo no modo de avaliação
    all_targets = torch.tensor([]).to(device)
    all_preds = torch.tensor([]).to(device)
    for inputs, targets in dataloader:
        inputs = inputs.to(device)
        targets = targets.to(device)
        preds = model(inputs)
        all_targets = torch.cat((all_targets, targets), 0)
        all_preds = torch.cat((all_preds, preds), 0)
    return all_preds.detach().cpu(), all_targets.detach().cpu()

def plot_metrics(model, device, dataloaders, phase='test'):
    preds, labels, scores = classify_predictions(model, device, dataloaders[phase])

    fpr, tpr, thresholds = metrics.roc_curve(labels, scores)
    auc = metrics.roc_auc_score(labels, preds)

    disp = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc)
    ind = np.argmin(np.abs(thresholds - 0.5))
    ax = disp.plot().ax_
    ax.scatter(fpr[ind], tpr[ind], color = 'red')
    ax.set_title('ROC Curve (red dot at threshold = 0.5)')

    cm = metrics.confusion_matrix(labels, preds)
    disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    #disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
    ax = disp.plot().ax_
    ax.set_title('Confusion Matrix -- counts')

    ncm = metrics.confusion_matrix(labels, preds, normalize='true')
    disp = metrics.ConfusionMatrixDisplay(confusion_matrix=ncm)
    ax = disp.plot().ax_
    ax.set_title('Confusion Matrix -- rates')

    TN, FP, FN, TP = cm[0,0], cm[0,1], cm[1,0], cm[1,1]
    N, P = TN + FP, TP + FN
    ACC = (TP + TN)/(P+N)
    TPR, FPR, FNR, TNR = TP/P, FP/N, FN/P, TN/N
    print(f'\nAt default threshold:')
    print(f' TN = {TN:5},  FP = {FP:5} -> N = {N:5}')
    print(f' FN = {FN:5},  TP = {TP:5} -> P = {P:5}')
    print(f'TNR = {TNR:5.3f}, FPR = {FPR:5.3f}')
    print(f'FNR = {FNR:5.3f}, TPR = {TPR:5.3f}')
    print(f'ACC = {ACC:6.3f}')

    return cm, fpr, tpr, thresholds, auc

# %%
plot_training_curves(training_curves_two_layer, phases=['train', 'val', 'test'])

# %%
plot_training_curves(training_curves_three_layer, phases=['train', 'val', 'test'])

# %% [markdown]
# Observando esse gráfico, podemos ver que nosso modelo está se sobreajustando ao conjunto de dados de treinamento. Como nossa curva de treinamento azul (perda) está diminuindo constantemente, na verdade vemos que a perda de validação aumenta. Vamos resolver o problema do sobreajuste nas próximas seções.

# %%
res = plot_metrics(three_layer_model, device, dataloaders, phase='test')
# Out:
# At default threshold:
#  TN =   267,  FP =   134 -> N =   401
#  FN =   103,  TP =   331 -> P =   434
# TNR = 0.666, FPR = 0.334
# FNR = 0.237, TPR = 0.763
# ACC =  0.716

# %% [markdown]
# Aqui, podemos ver a curva ROC e a matriz de confusão que foram abordadas no módulo. Parece que nosso modelo está prevendo incorretamente um abalone jovem como abalone adulto em uma taxa maior do que vice-versa.

# %% [markdown]
# ## Recursos adicionais
# Para a primeira rodada de seleção de atributos, optamos por usar apenas recursos numéricos. No entanto, estamos perdendo algumas informações importantes sobre os abalones ao não incluir seu sexo em nosso modelo. Para traduzir esse recurso ternário de nosso conjunto de dados para o modelo, usaremos a codificação one-hot. Agora, criaremos um atributo para cada uma das opções diferentes e atribuiremos o valor 1 se a amostra for um membro dessa classe e 0 para as outras. As estratégias de codificação podem ser simples, como esse método one-hot, ou podem ser muito mais complexas, como aprenderemos mais adiante no curso.

# %%
# Inserir os novos atributos de codificação one-hot
encoded_df = df.copy(True)
encoded_df.insert(1, 'M', 0)
encoded_df.insert(1, 'F', 0)
encoded_df.insert(1, 'I', 0)
encoded_df.loc[(df['Sex'] == 'M'), 'M'] = 1
encoded_df.loc[(df['Sex'] == 'F'), 'F'] = 1
encoded_df.loc[(df['Sex'] == 'I'), 'I'] = 1
encoded_column_names = column_names[:]
encoded_column_names.insert(1,"M")
encoded_column_names.insert(1,"F")
encoded_column_names.insert(1,"I")
encoded_df.head()
# Out:
#   Sex  I  F  M  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0   M  0  0  1   0.455     0.365   0.095        0.5140          0.2245
# 1   M  0  0  1   0.350     0.265   0.090        0.2255          0.0995
# 2   F  0  1  0   0.530     0.420   0.135        0.6770          0.2565
# 3   M  0  0  1   0.440     0.365   0.125        0.5160          0.2155
# 4   I  1  0  0   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weights  Rings  Old
# 0          0.1010          0.150     15    1
# 1          0.0485          0.070      7    0
# 2          0.1415          0.210      9    0
# 3          0.1140          0.155     10    1
# 4          0.0395          0.055      7    0

# %%
encoded_feature_columns = encoded_column_names[1:8]
print(encoded_feature_columns)
label_column = 'Old'

df.head()
# Out:
# ['I', 'F', 'M', 'Length', 'Diameter', 'Height', 'Whole weight']
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weights  Rings  Old
# 0          0.150     15    1
# 1          0.070      7    0
# 2          0.210      9    0
# 3          0.155     10    1
# 4          0.055      7    0

# %% [markdown]
# ### Divisão de treinamento-validação-teste e padronização
#
# Novamente, queremos realizar uma divisão de treinamento-validação-teste em nosso conjunto de dados. No entanto, queremos garantir que não realizemos a padronização em nossos novos atributos que são codificações one-hot!

# %%
# Aqui, usaremos o ColumnTransformer novamente para realizar a padronização dos dados. No entanto, estamos realizando essa padronização apenas nos atributos numéricos,
# NÃO nos atributos codificados em one-hot, então especificamos isso no construtor do ColumnTransformer.
ct = ColumnTransformer([('numerical_features', StandardScaler(), numerical_feature_columns)], remainder='passthrough')

encoded_train_dataset, encoded_test_dataset, encoded_val_dataset = train_test_val_split(encoded_df, encoded_feature_columns, label_column, ct)

# %% [markdown]
# ### Definição e hiperparâmetros do modelo

# %%
# Configuração do dispositivo (treinar nosso modelo na GPU se estiver disponível, o que é muito mais rápido)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hiperparâmetros

input_size = len(encoded_feature_columns) # Garantir que nosso tamanho de entrada inclua os novos atributos
hidden_size1 = 64
hidden_size2 = 64
hidden_size3 = 64
num_classes = 2

# Parâmetros externos de treinamento
batch_size = 10
learning_rate = 0.001
num_epochs = 50

# %%
three_layer_encoded_model = SimpleClassifier3Layer(input_size, hidden_size1, hidden_size2, hidden_size3, num_classes).to(device)
print(three_layer_encoded_model)
# Out:
# SimpleClassifier3Layer(
#   (layers): Sequential(
#     (0): Linear(in_features=7, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Preparação de dados finais

# %%
# Configurar conjuntos de dados e DataLoaders do Pytorch

dataloaders = {'train': DataLoader(encoded_train_dataset, batch_size=batch_size),
               'val': DataLoader(encoded_val_dataset, batch_size=batch_size),
               'test': DataLoader(encoded_test_dataset, batch_size=batch_size)}

dataset_sizes = {'train': len(encoded_train_dataset),
                 'val': len(encoded_val_dataset),
                 'test': len(encoded_test_dataset)}
print(f'dataset_sizes = {dataset_sizes}')
# Out:
# dataset_sizes = {'train': 2506, 'val': 836, 'test': 835}

# %%
# Perda e otimizador
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(three_layer_encoded_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

three_layer_encoded_model, training_curves_three_layer_encoded = train_model(three_layer_encoded_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5305 Acc: 0.7326
# val   Loss: 0.4425 Acc: 0.7859
# test  Loss: 0.5100 Acc: 0.7293
#
# Epoch 2/50
# ----------
# train Loss: 0.5075 Acc: 0.7442
# val   Loss: 0.4410 Acc: 0.7895
# test  Loss: 0.5071 Acc: 0.7317
#
# Epoch 3/50
# ----------
# train Loss: 0.5029 Acc: 0.7478
# val   Loss: 0.4407 Acc: 0.7919
# test  Loss: 0.5061 Acc: 0.7305
#
# Epoch 4/50
# ----------
# train Loss: 0.4994 Acc: 0.7458
# val   Loss: 0.4406 Acc: 0.7907
# test  Loss: 0.5059 Acc: 0.7257
#
# Epoch 5/50
# ----------
# train Loss: 0.4963 Acc: 0.7498
# val   Loss: 0.4405 Acc: 0.7919
# test  Loss: 0.5057 Acc: 0.7234
#
# Epoch 6/50
# ----------
# train Loss: 0.4920 Acc: 0.7470
# val   Loss: 0.4405 Acc: 0.7931
# test  Loss: 0.5053 Acc: 0.7281
#
# Epoch 7/50
# ----------
# train Loss: 0.4898 Acc: 0.7490
# val   Loss: 0.4410 Acc: 0.8002
# test  Loss: 0.5055 Acc: 0.7269
#
# Epoch 8/50
# ----------
# train Loss: 0.4880 Acc: 0.7518
# val   Loss: 0.4415 Acc: 0.8014
# test  Loss: 0.5054 Acc: 0.7269
#
# Epoch 9/50
# ----------
# train Loss: 0.4866 Acc: 0.7530
# val   Loss: 0.4416 Acc: 0.7967
# test  Loss: 0.5056 Acc: 0.7293
#
# Epoch 10/50
# ----------
# train Loss: 0.4851 Acc: 0.7526
# val   Loss: 0.4414 Acc: 0.7967
# test  Loss: 0.5058 Acc: 0.7329
#
# Epoch 11/50
# ----------
# train Loss: 0.4837 Acc: 0.7518
# val   Loss: 0.4413 Acc: 0.7978
# test  Loss: 0.5061 Acc: 0.7305
#
# Epoch 12/50
# ----------
# train Loss: 0.4825 Acc: 0.7514
# val   Loss: 0.4417 Acc: 0.7955
# test  Loss: 0.5065 Acc: 0.7281
#
# Epoch 13/50
# ----------
# train Loss: 0.4812 Acc: 0.7542
# val   Loss: 0.4419 Acc: 0.7990
# test  Loss: 0.5071 Acc: 0.7269
#
# Epoch 14/50
# ----------
# train Loss: 0.4799 Acc: 0.7554
# val   Loss: 0.4423 Acc: 0.7990
# test  Loss: 0.5075 Acc: 0.7269
#
# Epoch 15/50
# ----------
# train Loss: 0.4789 Acc: 0.7562
# val   Loss: 0.4425 Acc: 0.8038
# test  Loss: 0.5078 Acc: 0.7246
#
# Epoch 16/50
# ----------
# train Loss: 0.4775 Acc: 0.7582
# val   Loss: 0.4430 Acc: 0.8026
# test  Loss: 0.5085 Acc: 0.7234
#
# Epoch 17/50
# ----------
# train Loss: 0.4766 Acc: 0.7578
# val   Loss: 0.4434 Acc: 0.8062
# test  Loss: 0.5089 Acc: 0.7246
#
# Epoch 18/50
# ----------
# train Loss: 0.4756 Acc: 0.7586
# val   Loss: 0.4439 Acc: 0.8038
# test  Loss: 0.5093 Acc: 0.7257
#
# Epoch 19/50
# ----------
# train Loss: 0.4745 Acc: 0.7590
# val   Loss: 0.4442 Acc: 0.8026
# test  Loss: 0.5098 Acc: 0.7246
#
# Epoch 20/50
# ----------
# train Loss: 0.4736 Acc: 0.7598
# val   Loss: 0.4450 Acc: 0.8038
# test  Loss: 0.5104 Acc: 0.7234
#
# Epoch 21/50
# ----------
# train Loss: 0.4728 Acc: 0.7586
# val   Loss: 0.4455 Acc: 0.8050
# test  Loss: 0.5112 Acc: 0.7246
#
# Epoch 22/50
# ----------
# train Loss: 0.4720 Acc: 0.7598
# val   Loss: 0.4459 Acc: 0.8074
# test  Loss: 0.5116 Acc: 0.7234
#
# Epoch 23/50
# ----------
# train Loss: 0.4712 Acc: 0.7598
# val   Loss: 0.4462 Acc: 0.8086
# test  Loss: 0.5120 Acc: 0.7210
#
# Epoch 24/50
# ----------
# train Loss: 0.4705 Acc: 0.7578
# val   Loss: 0.4467 Acc: 0.8110
# test  Loss: 0.5125 Acc: 0.7234
#
# Epoch 25/50
# ----------
# train Loss: 0.4697 Acc: 0.7582
# val   Loss: 0.4467 Acc: 0.8110
# test  Loss: 0.5128 Acc: 0.7234
#
# Epoch 26/50
# ----------
# train Loss: 0.4692 Acc: 0.7582
# val   Loss: 0.4469 Acc: 0.8110
# test  Loss: 0.5132 Acc: 0.7234
#
# Epoch 27/50
# ----------
# train Loss: 0.4684 Acc: 0.7586
# val   Loss: 0.4471 Acc: 0.8110
# test  Loss: 0.5134 Acc: 0.7210
#
# Epoch 28/50
# ----------
# train Loss: 0.4679 Acc: 0.7586
# val   Loss: 0.4473 Acc: 0.8086
# test  Loss: 0.5139 Acc: 0.7222
#
# Epoch 29/50
# ----------
# train Loss: 0.4673 Acc: 0.7590
# val   Loss: 0.4472 Acc: 0.8086
# test  Loss: 0.5141 Acc: 0.7210
#
# Epoch 30/50
# ----------
# train Loss: 0.4668 Acc: 0.7618
# val   Loss: 0.4469 Acc: 0.8086
# test  Loss: 0.5144 Acc: 0.7210
#
# Epoch 31/50
# ----------
# train Loss: 0.4661 Acc: 0.7622
# val   Loss: 0.4473 Acc: 0.8086
# test  Loss: 0.5149 Acc: 0.7222
#
# Epoch 32/50
# ----------
# train Loss: 0.4657 Acc: 0.7618
# val   Loss: 0.4473 Acc: 0.8098
# test  Loss: 0.5150 Acc: 0.7210
#
# Epoch 33/50
# ----------
# train Loss: 0.4652 Acc: 0.7626
# val   Loss: 0.4476 Acc: 0.8098
# test  Loss: 0.5155 Acc: 0.7210
#
# Epoch 34/50
# ----------
# train Loss: 0.4647 Acc: 0.7646
# val   Loss: 0.4474 Acc: 0.8110
# test  Loss: 0.5158 Acc: 0.7210
#
# Epoch 35/50
# ----------
# train Loss: 0.4642 Acc: 0.7650
# val   Loss: 0.4474 Acc: 0.8098
# test  Loss: 0.5160 Acc: 0.7198
#
# Epoch 36/50
# ----------
# train Loss: 0.4638 Acc: 0.7650
# val   Loss: 0.4472 Acc: 0.8098
# test  Loss: 0.5162 Acc: 0.7198
#
# Epoch 37/50
# ----------
# train Loss: 0.4634 Acc: 0.7654
# val   Loss: 0.4474 Acc: 0.8074
# test  Loss: 0.5166 Acc: 0.7198
#
# Epoch 38/50
# ----------
# train Loss: 0.4630 Acc: 0.7662
# val   Loss: 0.4472 Acc: 0.8074
# test  Loss: 0.5169 Acc: 0.7198
#
# Epoch 39/50
# ----------
# train Loss: 0.4626 Acc: 0.7670
# val   Loss: 0.4472 Acc: 0.8062
# test  Loss: 0.5172 Acc: 0.7210
#
# Epoch 40/50
# ----------
# train Loss: 0.4622 Acc: 0.7670
# val   Loss: 0.4470 Acc: 0.8062
# test  Loss: 0.5175 Acc: 0.7210
#
# Epoch 41/50
# ----------
# train Loss: 0.4619 Acc: 0.7666
# val   Loss: 0.4471 Acc: 0.8062
# test  Loss: 0.5178 Acc: 0.7234
#
# Epoch 42/50
# ----------
# train Loss: 0.4615 Acc: 0.7662
# val   Loss: 0.4470 Acc: 0.8050
# test  Loss: 0.5181 Acc: 0.7234
#
# Epoch 43/50
# ----------
# train Loss: 0.4612 Acc: 0.7670
# val   Loss: 0.4469 Acc: 0.8062
# test  Loss: 0.5183 Acc: 0.7222
#
# Epoch 44/50
# ----------
# train Loss: 0.4609 Acc: 0.7674
# val   Loss: 0.4469 Acc: 0.8074
# test  Loss: 0.5185 Acc: 0.7234
#
# Epoch 45/50
# ----------
# train Loss: 0.4606 Acc: 0.7670
# val   Loss: 0.4469 Acc: 0.8074
# test  Loss: 0.5187 Acc: 0.7222
#
# Epoch 46/50
# ----------
# train Loss: 0.4603 Acc: 0.7658
# val   Loss: 0.4468 Acc: 0.8074
# test  Loss: 0.5189 Acc: 0.7246
#
# Epoch 47/50
# ----------
# train Loss: 0.4600 Acc: 0.7670
# val   Loss: 0.4467 Acc: 0.8062
# test  Loss: 0.5191 Acc: 0.7234
#
# Epoch 48/50
# ----------
# train Loss: 0.4598 Acc: 0.7678
# val   Loss: 0.4468 Acc: 0.8062
# test  Loss: 0.5193 Acc: 0.7234
#
# Epoch 49/50
# ----------
# train Loss: 0.4595 Acc: 0.7682
# val   Loss: 0.4467 Acc: 0.8062
# test  Loss: 0.5196 Acc: 0.7234
#
# Epoch 50/50
# ----------
# train Loss: 0.4593 Acc: 0.7690
# val   Loss: 0.4467 Acc: 0.8062
# test  Loss: 0.5197 Acc: 0.7222
#
# Training complete in 0m 16s
# Best val Acc: 0.811005 at epoch 23

# %% [markdown]
# Ao incluir esses novos atributos, observamos pouca mudança em nosso desempenho geral, o que indica que esses novos atributos não estão oferecendo um ganho significativo de informações.

# %% [markdown]
# ### Curvas de treinamento e métricas

# %%
plot_training_curves(training_curves_three_layer_encoded, phases=['train', 'val', 'test'])

# %% [markdown]
# Além disso, parece que nosso modelo ainda está se sobreajustando ao conjunto de dados com base nesses gráficos.

# %%
res = plot_metrics(three_layer_encoded_model, device, dataloaders, phase='test')
# Out:
# At default threshold:
#  TN =   255,  FP =   146 -> N =   401
#  FN =    88,  TP =   346 -> P =   434
# TNR = 0.636, FPR = 0.364
# FNR = 0.203, TPR = 0.797
# ACC =  0.720

# %% [markdown]
# ## Regularização e *dropout*
#
# Um dos principais assuntos abordados neste módulo foram os métodos para evitar o sobreajuste. Ao analisar os gráficos de treinamento acima, podemos ver que o modelo teve um sobreajuste significativo ao conjunto de dados de treinamento. Para combater isso, temos algumas ferramentas à nossa disposição.
#
# O PyTorch possui dois dos métodos que discutimos, regularização e *dropout*, incorporados. Vamos examinar como ambos afetam o desempenho do modelo.
#
# # Regularização:
# Evita que os pesos sejam muito altos, para que o modelo não fique "Super treinado" aos dados apresentados.
#
# # DropOut:
# Desliga um neuronio aleatorio durante as epocas de treinamento, para evitar que os demais sejam super dependentes do mesmo.

# %% [markdown]
# ### Regularização

# %%
# Redefinir o modelo
three_layer_encoded_l2_model = SimpleClassifier3Layer(input_size, hidden_size1, hidden_size2, hidden_size3,
                         num_classes).to(device)
print(three_layer_encoded_l2_model)
# Out:
# SimpleClassifier3Layer(
#   (layers): Sequential(
#     (0): Linear(in_features=7, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
# Perda e otimizador
criterion = nn.CrossEntropyLoss()
# Ao adicionar um termo weight_decay ao otimizador, estamos incluindo a regularização L2
optimizer = torch.optim.Adam(three_layer_encoded_l2_model.parameters(), lr=learning_rate, weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

three_layer_encoded_l2_model, training_curves_three_layer_encoded_l2 = train_model(three_layer_encoded_l2_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5353 Acc: 0.7338
# val   Loss: 0.4557 Acc: 0.7835
# test  Loss: 0.5198 Acc: 0.7305
#
# Epoch 2/50
# ----------
# train Loss: 0.5129 Acc: 0.7398
# val   Loss: 0.4535 Acc: 0.7859
# test  Loss: 0.5163 Acc: 0.7269
#
# Epoch 3/50
# ----------
# train Loss: 0.5103 Acc: 0.7410
# val   Loss: 0.4528 Acc: 0.7883
# test  Loss: 0.5150 Acc: 0.7281
#
# Epoch 4/50
# ----------
# train Loss: 0.5087 Acc: 0.7426
# val   Loss: 0.4524 Acc: 0.7895
# test  Loss: 0.5142 Acc: 0.7257
#
# Epoch 5/50
# ----------
# train Loss: 0.5076 Acc: 0.7450
# val   Loss: 0.4523 Acc: 0.7895
# test  Loss: 0.5138 Acc: 0.7269
#
# Epoch 6/50
# ----------
# train Loss: 0.5068 Acc: 0.7442
# val   Loss: 0.4524 Acc: 0.7907
# test  Loss: 0.5135 Acc: 0.7269
#
# Epoch 7/50
# ----------
# train Loss: 0.5061 Acc: 0.7454
# val   Loss: 0.4527 Acc: 0.7919
# test  Loss: 0.5133 Acc: 0.7293
#
# Epoch 8/50
# ----------
# train Loss: 0.5054 Acc: 0.7462
# val   Loss: 0.4529 Acc: 0.7919
# test  Loss: 0.5132 Acc: 0.7305
#
# Epoch 9/50
# ----------
# train Loss: 0.5049 Acc: 0.7462
# val   Loss: 0.4530 Acc: 0.7919
# test  Loss: 0.5131 Acc: 0.7317
#
# Epoch 10/50
# ----------
# train Loss: 0.5044 Acc: 0.7458
# val   Loss: 0.4531 Acc: 0.7919
# test  Loss: 0.5130 Acc: 0.7305
#
# Epoch 11/50
# ----------
# train Loss: 0.5040 Acc: 0.7458
# val   Loss: 0.4532 Acc: 0.7907
# test  Loss: 0.5130 Acc: 0.7305
#
# Epoch 12/50
# ----------
# train Loss: 0.5037 Acc: 0.7462
# val   Loss: 0.4533 Acc: 0.7919
# test  Loss: 0.5129 Acc: 0.7293
#
# Epoch 13/50
# ----------
# train Loss: 0.5033 Acc: 0.7474
# val   Loss: 0.4533 Acc: 0.7919
# test  Loss: 0.5128 Acc: 0.7293
#
# Epoch 14/50
# ----------
# train Loss: 0.5030 Acc: 0.7482
# val   Loss: 0.4532 Acc: 0.7919
# test  Loss: 0.5127 Acc: 0.7305
#
# Epoch 15/50
# ----------
# train Loss: 0.5027 Acc: 0.7490
# val   Loss: 0.4531 Acc: 0.7931
# test  Loss: 0.5126 Acc: 0.7305
#
# Epoch 16/50
# ----------
# train Loss: 0.5024 Acc: 0.7490
# val   Loss: 0.4529 Acc: 0.7931
# test  Loss: 0.5125 Acc: 0.7293
#
# Epoch 17/50
# ----------
# train Loss: 0.5021 Acc: 0.7486
# val   Loss: 0.4527 Acc: 0.7919
# test  Loss: 0.5123 Acc: 0.7293
#
# Epoch 18/50
# ----------
# train Loss: 0.5019 Acc: 0.7498
# val   Loss: 0.4524 Acc: 0.7919
# test  Loss: 0.5122 Acc: 0.7281
#
# Epoch 19/50
# ----------
# train Loss: 0.5016 Acc: 0.7502
# val   Loss: 0.4521 Acc: 0.7919
# test  Loss: 0.5120 Acc: 0.7281
#
# Epoch 20/50
# ----------
# train Loss: 0.5014 Acc: 0.7506
# val   Loss: 0.4517 Acc: 0.7931
# test  Loss: 0.5118 Acc: 0.7281
#
# Epoch 21/50
# ----------
# train Loss: 0.5012 Acc: 0.7506
# val   Loss: 0.4513 Acc: 0.7931
# test  Loss: 0.5116 Acc: 0.7281
#
# Epoch 22/50
# ----------
# train Loss: 0.5010 Acc: 0.7506
# val   Loss: 0.4511 Acc: 0.7931
# test  Loss: 0.5115 Acc: 0.7293
#
# Epoch 23/50
# ----------
# train Loss: 0.5007 Acc: 0.7510
# val   Loss: 0.4507 Acc: 0.7931
# test  Loss: 0.5113 Acc: 0.7293
#
# Epoch 24/50
# ----------
# train Loss: 0.5006 Acc: 0.7494
# val   Loss: 0.4504 Acc: 0.7931
# test  Loss: 0.5112 Acc: 0.7293
#
# Epoch 25/50
# ----------
# train Loss: 0.5004 Acc: 0.7502
# val   Loss: 0.4500 Acc: 0.7943
# test  Loss: 0.5110 Acc: 0.7293
#
# Epoch 26/50
# ----------
# train Loss: 0.5002 Acc: 0.7502
# val   Loss: 0.4496 Acc: 0.7943
# test  Loss: 0.5108 Acc: 0.7293
#
# Epoch 27/50
# ----------
# train Loss: 0.5000 Acc: 0.7502
# val   Loss: 0.4492 Acc: 0.7931
# test  Loss: 0.5107 Acc: 0.7293
#
# Epoch 28/50
# ----------
# train Loss: 0.4999 Acc: 0.7506
# val   Loss: 0.4487 Acc: 0.7931
# test  Loss: 0.5105 Acc: 0.7293
#
# Epoch 29/50
# ----------
# train Loss: 0.4998 Acc: 0.7506
# val   Loss: 0.4483 Acc: 0.7931
# test  Loss: 0.5103 Acc: 0.7293
#
# Epoch 30/50
# ----------
# train Loss: 0.4996 Acc: 0.7510
# val   Loss: 0.4479 Acc: 0.7907
# test  Loss: 0.5102 Acc: 0.7293
#
# Epoch 31/50
# ----------
# train Loss: 0.4995 Acc: 0.7510
# val   Loss: 0.4475 Acc: 0.7907
# test  Loss: 0.5100 Acc: 0.7293
#
# Epoch 32/50
# ----------
# train Loss: 0.4993 Acc: 0.7506
# val   Loss: 0.4472 Acc: 0.7919
# test  Loss: 0.5099 Acc: 0.7293
#
# Epoch 33/50
# ----------
# train Loss: 0.4992 Acc: 0.7506
# val   Loss: 0.4469 Acc: 0.7919
# test  Loss: 0.5098 Acc: 0.7293
#
# Epoch 34/50
# ----------
# train Loss: 0.4991 Acc: 0.7502
# val   Loss: 0.4465 Acc: 0.7919
# test  Loss: 0.5097 Acc: 0.7293
#
# Epoch 35/50
# ----------
# train Loss: 0.4990 Acc: 0.7506
# val   Loss: 0.4463 Acc: 0.7919
# test  Loss: 0.5096 Acc: 0.7293
#
# Epoch 36/50
# ----------
# train Loss: 0.4989 Acc: 0.7506
# val   Loss: 0.4460 Acc: 0.7919
# test  Loss: 0.5095 Acc: 0.7293
#
# Epoch 37/50
# ----------
# train Loss: 0.4988 Acc: 0.7510
# val   Loss: 0.4457 Acc: 0.7931
# test  Loss: 0.5094 Acc: 0.7293
#
# Epoch 38/50
# ----------
# train Loss: 0.4987 Acc: 0.7514
# val   Loss: 0.4455 Acc: 0.7931
# test  Loss: 0.5094 Acc: 0.7293
#
# Epoch 39/50
# ----------
# train Loss: 0.4986 Acc: 0.7522
# val   Loss: 0.4452 Acc: 0.7931
# test  Loss: 0.5093 Acc: 0.7293
#
# Epoch 40/50
# ----------
# train Loss: 0.4985 Acc: 0.7518
# val   Loss: 0.4450 Acc: 0.7931
# test  Loss: 0.5093 Acc: 0.7293
#
# Epoch 41/50
# ----------
# train Loss: 0.4985 Acc: 0.7518
# val   Loss: 0.4448 Acc: 0.7931
# test  Loss: 0.5092 Acc: 0.7293
#
# Epoch 42/50
# ----------
# train Loss: 0.4984 Acc: 0.7514
# val   Loss: 0.4446 Acc: 0.7931
# test  Loss: 0.5092 Acc: 0.7293
#
# Epoch 43/50
# ----------
# train Loss: 0.4983 Acc: 0.7514
# val   Loss: 0.4444 Acc: 0.7943
# test  Loss: 0.5091 Acc: 0.7293
#
# Epoch 44/50
# ----------
# train Loss: 0.4983 Acc: 0.7522
# val   Loss: 0.4443 Acc: 0.7943
# test  Loss: 0.5091 Acc: 0.7293
#
# Epoch 45/50
# ----------
# train Loss: 0.4982 Acc: 0.7518
# val   Loss: 0.4441 Acc: 0.7943
# test  Loss: 0.5091 Acc: 0.7293
#
# Epoch 46/50
# ----------
# train Loss: 0.4982 Acc: 0.7518
# val   Loss: 0.4440 Acc: 0.7943
# test  Loss: 0.5091 Acc: 0.7293
#
# Epoch 47/50
# ----------
# train Loss: 0.4981 Acc: 0.7514
# val   Loss: 0.4438 Acc: 0.7955
# test  Loss: 0.5090 Acc: 0.7293
#
# Epoch 48/50
# ----------
# train Loss: 0.4981 Acc: 0.7514
# val   Loss: 0.4437 Acc: 0.7955
# test  Loss: 0.5090 Acc: 0.7293
#
# Epoch 49/50
# ----------
# train Loss: 0.4980 Acc: 0.7510
# val   Loss: 0.4436 Acc: 0.7955
# test  Loss: 0.5090 Acc: 0.7293
#
# Epoch 50/50
# ----------
# train Loss: 0.4980 Acc: 0.7506
# val   Loss: 0.4434 Acc: 0.7955
# test  Loss: 0.5090 Acc: 0.7305
#
# Training complete in 0m 22s
# Best val Acc: 0.795455 at epoch 46

# %% [markdown]
# #### Métricas e curvas de treinamento

# %%
plot_training_curves(training_curves_three_layer_encoded_l2, phases=['train', 'val', 'test'])

# %% [markdown]
# Observando os gráficos acima, não vemos o mesmo comportamento de sobreajuste no conjunto de validação, mas ainda há outros métodos que podemos usar para melhorar ainda mais a generalização.

# %%
res = plot_metrics(three_layer_encoded_l2_model, device, dataloaders, phase='test')
# Out:
# At default threshold:
#  TN =   248,  FP =   153 -> N =   401
#  FN =    73,  TP =   361 -> P =   434
# TNR = 0.618, FPR = 0.382
# FNR = 0.168, TPR = 0.832
# ACC =  0.729

# %% [markdown]
# TN (True Negatives): 248
#
# O número de exemplos negativos corretamente classificados como negativo
# s.
# FP (False Positives): 53
#
# O número de exemplos negativos incorretamente classificados como posit
# ivos.
# FN (False Negative): 73
#
# O número de exemplos positivos incorretamente classificados como ne
# gativos.
# TP (True Posities): 361
#
# O número de exemplos positivos corretamente classificados como
#  positivos.
# N (Total Negatives): 41 (TN + FP)
#
# O total de exemp
# los negativos.
# P (Total Positives) 434 (FN + TP)
#
# O total de ex
# emplos positivos.
# TNR (True Negative Rate ou Specificit): 0.618 (TN / N)
#
# A proporção de exemplos negativos corretamente classificados em relação ao total de
#  exemplos negativos.
# FPR (False Positive ate): 0.382 (FP / N)
#
# A proporção de exemplos negativos incorretamente classificados em relação ao total
#  de exemplos negativos.
# FNR (False Negative Rate ou Mis Rate): 0.168 (FN / P)
#
# A proporção de exemplos positivos incorretamente classificados em relação ao to
# tal de exemplos positivos.
# TPR (True Positive Rate ou Sensitivityou Recall): 0.832 (TP / P)
#
# A proporção de exemplos positivos corretamente classificados em relação ao
#  total de exemplos positivos.
# ACC (Accuracy: 0.729 ((TP + TN) / (P + N))
#
# A acurácia geral do modelo, que é a proporção de exemplos corretamente classificados em relação ao total de exemplos.

# %% [markdown]
# ### *Dropout*

# %%
# Configuração do dispositivo (treinar nosso modelo na GPU se estiver disponível, o que é muito mais rápido)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hiperparâmetros

# Arquitetura do modelo
input_size = len(encoded_feature_columns)
hidden_size1 = 64
hidden_size2 = 64
hidden_size3 = 64
num_classes = 2
dropout = .25

# Parâmetros externos de treinamento
batch_size = 10
learning_rate = 0.001
num_epochs = 50

# %%
# Modelo de classificação simples com três camadas ocultas e dropout
class SimpleClassifier3LayerDropout(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, num_classes, dropout):
        super(SimpleClassifier3LayerDropout, self).__init__()
        self.dropout = nn.Dropout(dropout) # Taxa de dropout
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size2, hidden_size3),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size3, num_classes),
        )

    def forward(self, x):
        return self.layers(x)

# %%
# Redefinir o modelo com dropout
three_layer_encoded_l2_dropout_model = SimpleClassifier3LayerDropout(input_size, hidden_size1, hidden_size2, hidden_size3,
                         num_classes, dropout).to(device)
print(three_layer_encoded_l2_dropout_model)
# Out:
# SimpleClassifier3LayerDropout(
#   (dropout): Dropout(p=0.25, inplace=False)
#   (layers): Sequential(
#     (0): Linear(in_features=7, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.25, inplace=False)
#     (9): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
# Perda e otimizador
criterion = nn.CrossEntropyLoss()
# Ao adicionar um termo weight_decay ao otimizador, estamos incluindo a regularização L2
optimizer = torch.optim.Adam(three_layer_encoded_l2_dropout_model.parameters(), lr=learning_rate, weight_decay=1e-2)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

three_layer_encoded_l2_dropout_model, training_curves_three_layer_encoded_l2_dropout = train_model(three_layer_encoded_l2_dropout_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.5544 Acc: 0.7259
# val   Loss: 0.4593 Acc: 0.7739
# test  Loss: 0.5213 Acc: 0.7341
#
# Epoch 2/50
# ----------
# train Loss: 0.5228 Acc: 0.7402
# val   Loss: 0.4629 Acc: 0.7799
# test  Loss: 0.5206 Acc: 0.7281
#
# Epoch 3/50
# ----------
# train Loss: 0.5190 Acc: 0.7442
# val   Loss: 0.4598 Acc: 0.7895
# test  Loss: 0.5181 Acc: 0.7317
#
# Epoch 4/50
# ----------
# train Loss: 0.5111 Acc: 0.7454
# val   Loss: 0.4570 Acc: 0.7895
# test  Loss: 0.5170 Acc: 0.7246
#
# Epoch 5/50
# ----------
# train Loss: 0.5149 Acc: 0.7438
# val   Loss: 0.4602 Acc: 0.7859
# test  Loss: 0.5190 Acc: 0.7281
#
# Epoch 6/50
# ----------
# train Loss: 0.5205 Acc: 0.7442
# val   Loss: 0.4584 Acc: 0.7895
# test  Loss: 0.5179 Acc: 0.7222
#
# Epoch 7/50
# ----------
# train Loss: 0.5193 Acc: 0.7454
# val   Loss: 0.4593 Acc: 0.7895
# test  Loss: 0.5184 Acc: 0.7222
#
# Epoch 8/50
# ----------
# train Loss: 0.5137 Acc: 0.7446
# val   Loss: 0.4629 Acc: 0.7931
# test  Loss: 0.5192 Acc: 0.7269
#
# Epoch 9/50
# ----------
# train Loss: 0.5182 Acc: 0.7438
# val   Loss: 0.4620 Acc: 0.7919
# test  Loss: 0.5202 Acc: 0.7257
#
# Epoch 10/50
# ----------
# train Loss: 0.5155 Acc: 0.7502
# val   Loss: 0.4618 Acc: 0.7907
# test  Loss: 0.5199 Acc: 0.7269
#
# Epoch 11/50
# ----------
# train Loss: 0.5161 Acc: 0.7462
# val   Loss: 0.4605 Acc: 0.7895
# test  Loss: 0.5184 Acc: 0.7293
#
# Epoch 12/50
# ----------
# train Loss: 0.5152 Acc: 0.7446
# val   Loss: 0.4626 Acc: 0.7907
# test  Loss: 0.5194 Acc: 0.7210
#
# Epoch 13/50
# ----------
# train Loss: 0.5129 Acc: 0.7458
# val   Loss: 0.4615 Acc: 0.7919
# test  Loss: 0.5188 Acc: 0.7198
#
# Epoch 14/50
# ----------
# train Loss: 0.5133 Acc: 0.7450
# val   Loss: 0.4579 Acc: 0.7919
# test  Loss: 0.5179 Acc: 0.7246
#
# Epoch 15/50
# ----------
# train Loss: 0.5155 Acc: 0.7462
# val   Loss: 0.4609 Acc: 0.7883
# test  Loss: 0.5189 Acc: 0.7281
#
# Epoch 16/50
# ----------
# train Loss: 0.5129 Acc: 0.7474
# val   Loss: 0.4584 Acc: 0.7919
# test  Loss: 0.5175 Acc: 0.7257
#
# Epoch 17/50
# ----------
# train Loss: 0.5158 Acc: 0.7518
# val   Loss: 0.4599 Acc: 0.7895
# test  Loss: 0.5186 Acc: 0.7269
#
# Epoch 18/50
# ----------
# train Loss: 0.5130 Acc: 0.7458
# val   Loss: 0.4575 Acc: 0.7919
# test  Loss: 0.5174 Acc: 0.7305
#
# Epoch 19/50
# ----------
# train Loss: 0.5131 Acc: 0.7498
# val   Loss: 0.4628 Acc: 0.7943
# test  Loss: 0.5185 Acc: 0.7269
#
# Epoch 20/50
# ----------
# train Loss: 0.5062 Acc: 0.7498
# val   Loss: 0.4554 Acc: 0.7919
# test  Loss: 0.5158 Acc: 0.7317
#
# Epoch 21/50
# ----------
# train Loss: 0.5112 Acc: 0.7494
# val   Loss: 0.4574 Acc: 0.7943
# test  Loss: 0.5166 Acc: 0.7293
#
# Epoch 22/50
# ----------
# train Loss: 0.5090 Acc: 0.7490
# val   Loss: 0.4556 Acc: 0.7931
# test  Loss: 0.5156 Acc: 0.7246
#
# Epoch 23/50
# ----------
# train Loss: 0.5106 Acc: 0.7466
# val   Loss: 0.4556 Acc: 0.7919
# test  Loss: 0.5157 Acc: 0.7246
#
# Epoch 24/50
# ----------
# train Loss: 0.5093 Acc: 0.7490
# val   Loss: 0.4560 Acc: 0.7943
# test  Loss: 0.5162 Acc: 0.7257
#
# Epoch 25/50
# ----------
# train Loss: 0.5111 Acc: 0.7474
# val   Loss: 0.4566 Acc: 0.7931
# test  Loss: 0.5163 Acc: 0.7281
#
# Epoch 26/50
# ----------
# train Loss: 0.5121 Acc: 0.7482
# val   Loss: 0.4561 Acc: 0.7931
# test  Loss: 0.5161 Acc: 0.7317
#
# Epoch 27/50
# ----------
# train Loss: 0.5099 Acc: 0.7502
# val   Loss: 0.4538 Acc: 0.7907
# test  Loss: 0.5155 Acc: 0.7281
#
# Epoch 28/50
# ----------
# train Loss: 0.5109 Acc: 0.7502
# val   Loss: 0.4574 Acc: 0.7943
# test  Loss: 0.5163 Acc: 0.7269
#
# Epoch 29/50
# ----------
# train Loss: 0.5124 Acc: 0.7490
# val   Loss: 0.4577 Acc: 0.7943
# test  Loss: 0.5165 Acc: 0.7269
#
# Epoch 30/50
# ----------
# train Loss: 0.5131 Acc: 0.7486
# val   Loss: 0.4578 Acc: 0.7943
# test  Loss: 0.5164 Acc: 0.7281
#
# Epoch 31/50
# ----------
# train Loss: 0.5097 Acc: 0.7442
# val   Loss: 0.4567 Acc: 0.7943
# test  Loss: 0.5160 Acc: 0.7281
#
# Epoch 32/50
# ----------
# train Loss: 0.5116 Acc: 0.7502
# val   Loss: 0.4537 Acc: 0.7919
# test  Loss: 0.5150 Acc: 0.7317
#
# Epoch 33/50
# ----------
# train Loss: 0.5113 Acc: 0.7486
# val   Loss: 0.4524 Acc: 0.7907
# test  Loss: 0.5150 Acc: 0.7317
#
# Epoch 34/50
# ----------
# train Loss: 0.5123 Acc: 0.7510
# val   Loss: 0.4530 Acc: 0.7919
# test  Loss: 0.5155 Acc: 0.7293
#
# Epoch 35/50
# ----------
# train Loss: 0.5126 Acc: 0.7494
# val   Loss: 0.4518 Acc: 0.7931
# test  Loss: 0.5147 Acc: 0.7317
#
# Epoch 36/50
# ----------
# train Loss: 0.5098 Acc: 0.7474
# val   Loss: 0.4535 Acc: 0.7931
# test  Loss: 0.5150 Acc: 0.7305
#
# Epoch 37/50
# ----------
# train Loss: 0.5082 Acc: 0.7494
# val   Loss: 0.4528 Acc: 0.7919
# test  Loss: 0.5148 Acc: 0.7329
#
# Epoch 38/50
# ----------
# train Loss: 0.5113 Acc: 0.7526
# val   Loss: 0.4523 Acc: 0.7931
# test  Loss: 0.5148 Acc: 0.7329
#
# Epoch 39/50
# ----------
# train Loss: 0.5106 Acc: 0.7498
# val   Loss: 0.4529 Acc: 0.7931
# test  Loss: 0.5150 Acc: 0.7329
#
# Epoch 40/50
# ----------
# train Loss: 0.5100 Acc: 0.7510
# val   Loss: 0.4519 Acc: 0.7919
# test  Loss: 0.5147 Acc: 0.7317
#
# Epoch 41/50
# ----------
# train Loss: 0.5111 Acc: 0.7506
# val   Loss: 0.4520 Acc: 0.7907
# test  Loss: 0.5147 Acc: 0.7329
#
# Epoch 42/50
# ----------
# train Loss: 0.5093 Acc: 0.7498
# val   Loss: 0.4520 Acc: 0.7931
# test  Loss: 0.5145 Acc: 0.7305
#
# Epoch 43/50
# ----------
# train Loss: 0.5068 Acc: 0.7514
# val   Loss: 0.4502 Acc: 0.7919
# test  Loss: 0.5142 Acc: 0.7317
#
# Epoch 44/50
# ----------
# train Loss: 0.5082 Acc: 0.7506
# val   Loss: 0.4508 Acc: 0.7907
# test  Loss: 0.5143 Acc: 0.7329
#
# Epoch 45/50
# ----------
# train Loss: 0.5129 Acc: 0.7474
# val   Loss: 0.4510 Acc: 0.7907
# test  Loss: 0.5144 Acc: 0.7329
#
# Epoch 46/50
# ----------
# train Loss: 0.5111 Acc: 0.7482
# val   Loss: 0.4512 Acc: 0.7919
# test  Loss: 0.5144 Acc: 0.7329
#
# Epoch 47/50
# ----------
# train Loss: 0.5094 Acc: 0.7490
# val   Loss: 0.4505 Acc: 0.7907
# test  Loss: 0.5142 Acc: 0.7329
#
# Epoch 48/50
# ----------
# train Loss: 0.5117 Acc: 0.7466
# val   Loss: 0.4508 Acc: 0.7919
# test  Loss: 0.5142 Acc: 0.7329
#
# Epoch 49/50
# ----------
# train Loss: 0.5081 Acc: 0.7514
# val   Loss: 0.4497 Acc: 0.7907
# test  Loss: 0.5139 Acc: 0.7329
#
# Epoch 50/50
# ----------
# train Loss: 0.5102 Acc: 0.7502
# val   Loss: 0.4497 Acc: 0.7919
# test  Loss: 0.5140 Acc: 0.7317
#
# Training complete in 0m 22s
# Best val Acc: 0.794258 at epoch 18

# %% [markdown]
# Nesse caso, incluir o *dropout* parece ter feito apenas uma pequena mudança em nossa precisão geral. Considerando que este é um modelo profundo relativamente simples (especialmente em comparação com algumas das redes focadas em visão que veremos no futuro), isso não é totalmente inesperado e o *dropout* pode não ser a melhor escolha para esse problema. No entanto, vamos investigar as curvas de treinamento abaixo.

# %% [markdown]
# #### Curvas de treinamento e métricas

# %%
plot_training_curves(training_curves_three_layer_encoded_l2_dropout, phases=['train', 'val', 'test'])

# %% [markdown]
# Ao analisar essas curvas, podemos ver que incluir o *dropout* melhorou a generalização do nosso modelo e evitou o sobreajuste.

# %%
res = plot_metrics(three_layer_encoded_l2_dropout_model, device, dataloaders, phase='test')
# Out:
# At default threshold:
#  TN =   239,  FP =   162 -> N =   401
#  FN =    66,  TP =   368 -> P =   434
# TNR = 0.596, FPR = 0.404
# FNR = 0.152, TPR = 0.848
# ACC =  0.727

# %% [markdown]
# ## Modelo de Regressão
# Agora, em vez de fazer apenas uma classificação binária para determinar se um abalone é jovem ou adulto, queremos prever o número exato de anéis. Podemos facilmente adaptar nosso modelo para realizar essa tarefa de regressão.

# %% [markdown]
# ### Preparação do conjunto de dados

# %%
regression_label_column = 'Rings' # Alterar apenas a coluna de rótulo
# Rings (anéis) também precisa ser do tipo float, caso contrário, nossa função de perda não funcionará
encoded_df[regression_label_column] = encoded_df[regression_label_column].astype('float32')
encoded_df.dtypes
# Out:
# Sex                object
# I                   int64
# F                   int64
# M                   int64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weights     float64
# Rings             float32
# Old                 int64
# dtype: object

# %% [markdown]
# ### Divisão de treinamento-validação-teste e padronização

# %%
ct = ColumnTransformer([('numerical_features', StandardScaler(), numerical_feature_columns)], remainder='passthrough')

regression_train_dataset, regression_test_dataset, regression_val_dataset = train_test_val_split(encoded_df, encoded_feature_columns, regression_label_column, ct)

# %% [markdown]
# ### Hiperparâmetros do modelo e definição

# %%
# Configuração do dispositivo (treinar nosso modelo na GPU se estiver disponível, o que é muito mais rápido)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hiperparâmetros

# Arquitetura do modelo
input_size = len(encoded_feature_columns)
hidden_size1 = 64
hidden_size2 = 64
hidden_size3 = 64
output_neurons = 1
dropout = .25

# Parâmetros externos de treinamento
batch_size = 10
learning_rate = 0.001
num_epochs = 50

# %%
# Modelo de regressão simples de três camadas ocultas com dropout
class SimpleRegressor(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, output_neurons, dropout):
        super(SimpleRegressor, self).__init__()
        self.dropout = nn.Dropout(dropout) # Taxa de dropout
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size2, hidden_size3),
            nn.ReLU(),
            self.dropout,
            nn.Linear(hidden_size3, output_neurons),
        )

    def forward(self, x):
        return self.layers(x)

# %%
regression_model = SimpleRegressor(input_size, hidden_size1, hidden_size2, hidden_size3, output_neurons, dropout).to(device)
print(regression_model)
# Out:
# SimpleRegressor(
#   (dropout): Dropout(p=0.25, inplace=False)
#   (layers): Sequential(
#     (0): Linear(in_features=7, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=64, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.25, inplace=False)
#     (6): Linear(in_features=64, out_features=64, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.25, inplace=False)
#     (9): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Preparação dos dados finais

# %%
# Configurar conjuntos de dados e DataLoaders do PyTorch

dataloaders = {'train': DataLoader(regression_train_dataset, batch_size=batch_size),
               'val': DataLoader(regression_val_dataset, batch_size=batch_size),
               'test': DataLoader(regression_test_dataset, batch_size=batch_size)}

dataset_sizes = {'train': len(regression_train_dataset),
                 'val': len(regression_val_dataset),
                 'test': len(regression_test_dataset)}
print(f'dataset_sizes = {dataset_sizes}')
# Out:
# dataset_sizes = {'train': 2506, 'val': 836, 'test': 835}

# %% [markdown]
# ### Treinando o modelo
#
# Vamos ajustar o procedimento de treinamento anterior para se adequar ao nosso problema de regressão.

# %%
# De https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

def train_regression_model(model, dataloaders, dataset_sizes, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = np.inf
    best_epoch = 0

    # Cada época possui uma fase de treinamento, validação e teste
    phases = ['train', 'val', 'test']

    # Acompanhe como a perda e a precisão evoluem durante o treinamento
    training_curves = {}
    for phase in phases:
        training_curves[phase+'_loss'] = []

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()  # Definir o modelo no modo de treinamento
            else:
                model.eval()   # Definir o modelo no modo de avaliação

            running_loss = 0.0

            # Iterar sobre os dados
            for inputs, targets in dataloaders[phase]:
                inputs = inputs.to(device)
                targets = targets.to(device) #

                # Zerar os gradientes dos parâmetros
                optimizer.zero_grad()

                # Propagação (forward)
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = torch.flatten(model(inputs))
                    loss = criterion(outputs, targets)

                    # Retropropagação (backward) e atualização dos pesos apenas na fase de treinamento
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Estatísticas
                running_loss += loss.item() * inputs.size(0)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            training_curves[phase+'_loss'].append(epoch_loss)

            print(f'{phase:5} Loss: {epoch_loss:.4f}')

            # Realizar uma cópia profunda do modelo se for a melhor precisão (com base na validação)
            if phase == 'val' and epoch_loss < best_loss:
                best_epoch = epoch
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Loss: {best_loss:4f} at epoch {best_epoch}')

    # Carregar os melhores pesos do modelo
    model.load_state_dict(best_model_wts)

    return model, training_curves

# %%
# Perda e otimizador
criterion = nn.MSELoss() # Perda de MSE em vez de CrossEntropy
optimizer = torch.optim.Adam(regression_model.parameters(), lr=learning_rate,
                             weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

regression_model, training_curves_regression = train_regression_model(regression_model, dataloaders, dataset_sizes,
                                     criterion, optimizer, scheduler, num_epochs=num_epochs)
# Out:
# Epoch 1/50
# ----------
# train Loss: 27.2733
# val   Loss: 6.9558
# test  Loss: 5.9300
#
# Epoch 2/50
# ----------
# train Loss: 12.1765
# val   Loss: 6.4331
# test  Loss: 5.5657
#
# Epoch 3/50
# ----------
# train Loss: 11.5638
# val   Loss: 6.4478
# test  Loss: 5.7207
#
# Epoch 4/50
# ----------
# train Loss: 10.0025
# val   Loss: 6.2955
# test  Loss: 5.4735
#
# Epoch 5/50
# ----------
# train Loss: 9.5178
# val   Loss: 6.3275
# test  Loss: 5.4755
#
# Epoch 6/50
# ----------
# train Loss: 9.5170
# val   Loss: 6.3055
# test  Loss: 5.5986
#
# Epoch 7/50
# ----------
# train Loss: 9.7104
# val   Loss: 6.3516
# test  Loss: 5.4682
#
# Epoch 8/50
# ----------
# train Loss: 9.3102
# val   Loss: 6.3744
# test  Loss: 5.4291
#
# Epoch 9/50
# ----------
# train Loss: 9.2857
# val   Loss: 6.4619
# test  Loss: 5.3962
#
# Epoch 10/50
# ----------
# train Loss: 9.0924
# val   Loss: 6.3364
# test  Loss: 5.4591
#
# Epoch 11/50
# ----------
# train Loss: 8.5492
# val   Loss: 6.2498
# test  Loss: 5.4890
#
# Epoch 12/50
# ----------
# train Loss: 8.8566
# val   Loss: 6.2227
# test  Loss: 5.4834
#
# Epoch 13/50
# ----------
# train Loss: 8.9312
# val   Loss: 6.3566
# test  Loss: 5.5251
#
# Epoch 14/50
# ----------
# train Loss: 8.3500
# val   Loss: 6.2733
# test  Loss: 5.3664
#
# Epoch 15/50
# ----------
# train Loss: 8.5922
# val   Loss: 6.2166
# test  Loss: 5.4096
#
# Epoch 16/50
# ----------
# train Loss: 8.2292
# val   Loss: 6.2453
# test  Loss: 5.5707
#
# Epoch 17/50
# ----------
# train Loss: 8.4253
# val   Loss: 6.3850
# test  Loss: 5.6131
#
# Epoch 18/50
# ----------
# train Loss: 8.2659
# val   Loss: 6.2449
# test  Loss: 5.3482
#
# Epoch 19/50
# ----------
# train Loss: 8.2545
# val   Loss: 6.1826
# test  Loss: 5.4161
#
# Epoch 20/50
# ----------
# train Loss: 8.3733
# val   Loss: 6.1935
# test  Loss: 5.4165
#
# Epoch 21/50
# ----------
# train Loss: 8.2012
# val   Loss: 6.2782
# test  Loss: 5.4543
#
# Epoch 22/50
# ----------
# train Loss: 8.0344
# val   Loss: 6.2240
# test  Loss: 5.3255
#
# Epoch 23/50
# ----------
# train Loss: 8.0774
# val   Loss: 6.2172
# test  Loss: 5.3664
#
# Epoch 24/50
# ----------
# train Loss: 8.1488
# val   Loss: 6.1567
# test  Loss: 5.4388
#
# Epoch 25/50
# ----------
# train Loss: 8.0771
# val   Loss: 6.2396
# test  Loss: 5.5365
#
# Epoch 26/50
# ----------
# train Loss: 8.4107
# val   Loss: 6.2276
# test  Loss: 5.3472
#
# Epoch 27/50
# ----------
# train Loss: 8.0411
# val   Loss: 6.1651
# test  Loss: 5.4434
#
# Epoch 28/50
# ----------
# train Loss: 8.0697
# val   Loss: 6.1418
# test  Loss: 5.3495
#
# Epoch 29/50
# ----------
# train Loss: 7.8061
# val   Loss: 6.1458
# test  Loss: 5.2989
#
# Epoch 30/50
# ----------
# train Loss: 7.8024
# val   Loss: 6.1558
# test  Loss: 5.3058
#
# Epoch 31/50
# ----------
# train Loss: 8.0339
# val   Loss: 6.1491
# test  Loss: 5.2730
#
# Epoch 32/50
# ----------
# train Loss: 7.7164
# val   Loss: 6.1170
# test  Loss: 5.3036
#
# Epoch 33/50
# ----------
# train Loss: 7.9198
# val   Loss: 6.1182
# test  Loss: 5.3306
#
# Epoch 34/50
# ----------
# train Loss: 7.7406
# val   Loss: 6.1106
# test  Loss: 5.3268
#
# Epoch 35/50
# ----------
# train Loss: 7.7762
# val   Loss: 6.1170
# test  Loss: 5.3041
#
# Epoch 36/50
# ----------
# train Loss: 7.7589
# val   Loss: 6.1028
# test  Loss: 5.3332
#
# Epoch 37/50
# ----------
# train Loss: 8.0698
# val   Loss: 6.0928
# test  Loss: 5.3207
#
# Epoch 38/50
# ----------
# train Loss: 8.0114
# val   Loss: 6.1272
# test  Loss: 5.3688
#
# Epoch 39/50
# ----------
# train Loss: 7.9482
# val   Loss: 6.1375
# test  Loss: 5.2803
#
# Epoch 40/50
# ----------
# train Loss: 7.7002
# val   Loss: 6.1041
# test  Loss: 5.2803
#
# Epoch 41/50
# ----------
# train Loss: 7.9729
# val   Loss: 6.1476
# test  Loss: 5.2736
#
# Epoch 42/50
# ----------
# train Loss: 7.7377
# val   Loss: 6.1565
# test  Loss: 5.2577
#
# Epoch 43/50
# ----------
# train Loss: 7.7732
# val   Loss: 6.1296
# test  Loss: 5.2728
#
# Epoch 44/50
# ----------
# train Loss: 7.6127
# val   Loss: 6.1072
# test  Loss: 5.3042
#
# Epoch 45/50
# ----------
# train Loss: 7.7062
# val   Loss: 6.0999
# test  Loss: 5.2817
#
# Epoch 46/50
# ----------
# train Loss: 7.8742
# val   Loss: 6.0929
# test  Loss: 5.2720
#
# Epoch 47/50
# ----------
# train Loss: 7.6833
# val   Loss: 6.1134
# test  Loss: 5.2477
#
# Epoch 48/50
# ----------
# train Loss: 7.7959
# val   Loss: 6.1509
# test  Loss: 5.2313
#
# Epoch 49/50
# ----------
# train Loss: 7.8218
# val   Loss: 6.1209
# test  Loss: 5.2519
#
# Epoch 50/50
# ----------
# train Loss: 7.7497
# val   Loss: 6.0998
# test  Loss: 5.2550
#
# Training complete in 0m 18s
# Best val Loss: 6.092797 at epoch 36

# %%
plot_training_curves(training_curves_regression, metrics=['loss'])

# %%
predicted_ages, true_ages = regress_predictions(regression_model, device, dataloaders['train'])
# Podemos ver que nossas previsões parecem sensatas em comparação com as idades dos abalones

# %%
predicted_ages
# Out:
# tensor([[10.7488],
#         [ 7.7338],
#         [11.2271],
#         ...,
#         [ 8.5672],
#         [11.0401],
#         [ 8.3603]])

# %%
true_ages
# Out:
# tensor([10.,  9.,  9.,  ...,  7., 14., 10.])

# %%
# Resultados do treinamento
plot_regression(regression_model, device, dataloaders['train'])

# %%
# Resultados de validação
plot_regression(regression_model, device, dataloaders['val'])

# %%
# Resultados dos testes
plot_regression(regression_model, device, dataloaders['test'])

# %% [markdown]
# ### Olhando para o futuro
# Agora que construímos uma base com PyTorch, seremos capazes de realizar muitas tarefas diferentes de aprendizagem de máquina. Primeiro, nos concentraremos no reconhecimento de dígitos manuscritos usando o conjunto de dados MNIST e usaremos esse conjunto de dados para introduzir arquiteturas mais complexas de redes neurais profundas.
